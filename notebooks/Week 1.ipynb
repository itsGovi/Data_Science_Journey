# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Day 1

# %% [markdown]
# ### Task 1 & 2

# %%
df = pd.read_csv('C:\\Users\\govar\\OneDrive\\Documents\\Data_Science_Journey\\data\\consultancy_data_5400.csv')
df.__len__
# Out:
# <bound method DataFrame.__len__ of       employee_id         full_name            department  \
# 0          670487   Patrick Sanchez  Engineering Delivery
# 1          146316     Megan Mcclain  Product Architecture
# 2           91161      Amanda Davis       Client Services
# 3          243962   Alyssa Gonzalez  Engineering Delivery
# 4          681453     Jennifer Cole  Engineering Delivery
# ...           ...               ...                   ...
# 5395        17844  Elizabeth Morrow  Engineering Delivery
# 5396       836591    Sophia Bennett           Design & UX
# 5397        23701       Clayton May           Design & UX
# 5398       370275    Danny Anderson           Design & UX
# 5399       428841     John Cardenas           Design & UX
#
#                       position   level   hire_date           city    country  \
# 0          Associate Developer   entry  2023-03-26       New York        USA
# 1           Solution Architect     mid  2020-05-19         Berlin    Germany
# 2     Client Success Associate   entry  2023-07-22      Singapore  Singapore
# 3          Associate Developer   entry  2022-07-05      Singapore  Singapore
# 4                QA Engineer I   entry  2022-11-07       New York        USA
# ...                        ...     ...         ...            ...        ...
# 5395      Development Director  senior  2017-03-11  San Francisco        USA
# 5396               Design Lead     mid  2020-08-14       New York        USA
# 5397             UI Designer I   entry  2022-08-16      Singapore  Singapore
# 5398         Design Strategist     mid  2021-05-30       New York        USA
# 5399    Lead Design Strategist  senior  2014-01-28       New York        USA
#
#         region  remote_work_ratio  ...  retention_risk  manager_id  \
# 0     Americas               24.7  ...             Low    605912.0
# 1         EMEA               37.3  ...          Medium         NaN
# 2         APAC               21.9  ...             Low    574842.0
# 3         APAC               23.2  ...             Low    914277.0
# 4     Americas               11.1  ...             Low    570871.0
# ...        ...                ...  ...             ...         ...
# 5395  Americas               40.2  ...             Low         NaN
# 5396  Americas               22.8  ...             Low         NaN
# 5397      APAC               25.3  ...             Low    520760.0
# 5398  Americas               25.7  ...             Low         NaN
# 5399  Americas               46.2  ...             Low         NaN
#
#       total_comp  team_lead_projects  direct_reports is_manager  \
# 0      132000.00                   0               0      False
# 1      176000.00                   1               0      False
# 2       98000.00                   0               0      False
# 3       98000.00                   0               0      False
# 4      130000.00                   0               0      False
# ...          ...                 ...             ...        ...
# 5395   396000.00                   2               0      False
# 5396   198432.62                   0               2       True
# 5397   110000.00                   0               0      False
# 5398   174000.00                   0               0      False
# 5399   532394.97                   2              10       True
#
#      management_level span_of_control management_premium  span_premium
# 0                 NaN             NaN               0.00             0
# 1                 NaN             NaN               0.00             0
# 2                 NaN             NaN               0.00             0
# 3                 NaN             NaN               0.00             0
# 4                 NaN             NaN               0.00             0
# ...               ...             ...                ...           ...
# 5395              NaN             NaN               0.00             0
# 5396              mid     Small (1-3)           34632.62          7800
# 5397              NaN             NaN               0.00             0
# 5398              NaN             NaN               0.00             0
# 5399           senior      Large (7+)          113794.97         54600
#
# [5400 rows x 44 columns]>

# %%
print("Number of rows: ", len(df))

df.info()

print(df.describe(include='all'))
# Out:
# Number of rows:  5400
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5400 entries, 0 to 5399
# Data columns (total 44 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   employee_id               5400 non-null   int64
#  1   full_name                 5400 non-null   object
#  2   department                5400 non-null   object
#  3   position                  5400 non-null   object
#  4   level                     5400 non-null   object
#  5   hire_date                 5400 non-null   object
#  6   city                      5400 non-null   object
#  7   country                   5400 non-null   object
#  8   region                    5400 non-null   object
#  9   remote_work_ratio         5400 non-null   float64
#  10  travel_percentage         5400 non-null   float64
#  11  base_salary               5400 non-null   int64
#  12  billing_rate              5400 non-null   int64
#  13  utilization_target        5400 non-null   int64
#  14  actual_utilization        5400 non-null   float64
#  15  primary_specialization    5400 non-null   object
#  16  secondary_specialization  5400 non-null   object
#  17  industry_expertise        5400 non-null   object
#  18  certifications            4718 non-null   object
#  19  performance_score         5400 non-null   float64
#  20  innovation_score          5400 non-null   float64
#  21  delivery_quality          5400 non-null   float64
#  22  active_projects           5400 non-null   int64
#  23  avg_project_complexity    5400 non-null   float64
#  24  avg_project_duration      5400 non-null   float64
#  25  avg_team_size             5400 non-null   float64
#  26  projects_on_time          5400 non-null   float64
#  27  project_satisfaction      5400 non-null   float64
#  28  training_hours            5400 non-null   int64
#  29  mentorship_hours          5400 non-null   int64
#  30  knowledge_sharing_score   5400 non-null   float64
#  31  promotion_readiness       5400 non-null   float64
#  32  engagement_score          5400 non-null   float64
#  33  flight_risk               5400 non-null   int64
#  34  retention_risk            5400 non-null   object
#  35  manager_id                2777 non-null   float64
#  36  total_comp                5400 non-null   float64
#  37  team_lead_projects        5400 non-null   int64
#  38  direct_reports            5400 non-null   int64
#  39  is_manager                5400 non-null   bool
#  40  management_level          496 non-null    object
#  41  span_of_control           477 non-null    object
#  42  management_premium        5400 non-null   float64
#  43  span_premium              5400 non-null   int64
# dtypes: bool(1), float64(17), int64(11), object(15)
# memory usage: 1.8+ MB
#           employee_id    full_name            department       position level  \
# count     5400.000000         5400                  5400           5400  5400
# unique            NaN         5202                     5             55     3
# top               NaN  Brian Perez  Engineering Delivery  Junior DevOps   mid
# freq              NaN            4                  1612            277  2144
# mean    500086.584630          NaN                   NaN            NaN   NaN
# std     287402.686801          NaN                   NaN            NaN   NaN
# min         63.000000          NaN                   NaN            NaN   NaN
# 25%     254712.500000          NaN                   NaN            NaN   NaN
# 50%     500614.000000          NaN                   NaN            NaN   NaN
# 75%     747426.750000          NaN                   NaN            NaN   NaN
# max     999600.000000          NaN                   NaN            NaN   NaN
#
#          hire_date      city country    region  remote_work_ratio  ...  \
# count         5400      5400    5400      5400        5400.000000  ...
# unique        2692         9       4         3                NaN  ...
# top     2023-07-06  New York     USA  Americas                NaN  ...
# freq             9      1890    2456      2456                NaN  ...
# mean           NaN       NaN     NaN       NaN          28.741574  ...
# std            NaN       NaN     NaN       NaN           9.614284  ...
# min            NaN       NaN     NaN       NaN          10.000000  ...
# 25%            NaN       NaN     NaN       NaN          21.700000  ...
# 50%            NaN       NaN     NaN       NaN          28.400000  ...
# 75%            NaN       NaN     NaN       NaN          36.000000  ...
# max            NaN       NaN     NaN       NaN          50.000000  ...
#
#         retention_risk     manager_id     total_comp  team_lead_projects  \
# count             5400    2777.000000    5400.000000         5400.000000
# unique               3            NaN            NaN                 NaN
# top                Low            NaN            NaN                 NaN
# freq              4186            NaN            NaN                 NaN
# mean               NaN  495820.460209  207131.904996            0.840556
# std                NaN  275658.484314  105411.649890            1.110968
# min                NaN    8948.000000   82000.000000            0.000000
# 25%                NaN  294301.000000  119000.000000            0.000000
# 50%                NaN  484405.000000  183000.000000            0.000000
# 75%                NaN  717307.000000  259000.000000            1.000000
# max                NaN  998944.000000  730115.610000            5.000000
#
#         direct_reports is_manager management_level span_of_control  \
# count      5400.000000       5400              496             477
# unique             NaN          2                2               3
# top                NaN      False              mid      Large (7+)
# freq               NaN       4904              383             219
# mean          0.514259        NaN              NaN             NaN
# std           1.899147        NaN              NaN             NaN
# min           0.000000        NaN              NaN             NaN
# 25%           0.000000        NaN              NaN             NaN
# 50%           0.000000        NaN              NaN             NaN
# 75%           0.000000        NaN              NaN             NaN
# max          10.000000        NaN              NaN             NaN
#
#        management_premium  span_premium
# count         5400.000000   5400.000000
# unique                NaN           NaN
# top                   NaN           NaN
# freq                  NaN           NaN
# mean          4844.127219   2285.370370
# std          17713.683031   8907.666546
# min              0.000000      0.000000
# 25%              0.000000      0.000000
# 50%              0.000000      0.000000
# 75%              0.000000      0.000000
# max         161286.060000  76050.000000
#
# [11 rows x 44 columns]

# %% [markdown]
# ### Task 3

# %%
engineering_df = df[df['department'] == 'Engineering Delivery'] 
pd.set_option('display.max_columns', None) 
print(engineering_df.head())
# Out:
#     employee_id         full_name            department             position  \
# 0        670487   Patrick Sanchez  Engineering Delivery  Associate Developer
# 3        243962   Alyssa Gonzalez  Engineering Delivery  Associate Developer
# 4        681453     Jennifer Cole  Engineering Delivery        QA Engineer I
# 5        291704   Abigail Shaffer  Engineering Delivery     Senior Developer
# 11       379201  Michele Williams  Engineering Delivery        Junior DevOps
#
#     level   hire_date           city    country    region  remote_work_ratio  \
# 0   entry  2023-03-26       New York        USA  Americas               24.7
# 3   entry  2022-07-05      Singapore  Singapore      APAC               23.2
# 4   entry  2022-11-07       New York        USA  Americas               11.1
# 5     mid  2021-09-06         Berlin         UK      EMEA               30.1
# 11  entry  2022-03-14  San Francisco        USA  Americas               13.6
#
#     travel_percentage  base_salary  billing_rate  utilization_target  \
# 0                 1.8       132000           250                  90
# 3                 4.5        98000           150                  90
# 4                 1.5       130000           250                  90
# 5                13.5       157000           250                  82
# 11                0.0       117000           200                  90
#
#     actual_utilization primary_specialization secondary_specialization  \
# 0                 79.4           Cloud Native             Cloud Native
# 3                 93.6     Mobile Development       Mobile Development
# 4                 77.2               Frontend                 Frontend
# 5                 79.9     Mobile Development                 Frontend
# 11                80.6                 DevOps                  Backend
#
#                                    industry_expertise  \
# 0                  Enterprise Software, Consumer Tech
# 3                  Social Impact, Enterprise Software
# 4   Industrial Tech, HealthTech, Enterprise Softwa...
# 5          HealthTech, Social Impact, Industrial Tech
# 11                           Industrial Tech, FinTech
#
#                                   certifications  performance_score  \
# 0                    Scrum Master, AWS Developer               3.65
# 3                    Azure Developer, Kubernetes               4.20
# 4                                   Scrum Master               3.42
# 5   AWS Developer, Azure Developer, Scrum Master               3.57
# 11                     AWS Developer, Kubernetes               3.50
#
#     innovation_score  delivery_quality  active_projects  \
# 0               66.9              78.6                2
# 3               71.3              83.1                2
# 4               75.7              87.0                2
# 5               79.8              69.5                4
# 11              87.3              76.0                2
#
#     avg_project_complexity  avg_project_duration  avg_team_size  \
# 0                      2.5                   8.5            5.5
# 3                      2.5                   4.0            4.5
# 4                      1.0                   3.0            7.0
# 5                      2.5                   8.5            5.8
# 11                     1.5                   9.5            6.0
#
#     projects_on_time  project_satisfaction  training_hours  mentorship_hours  \
# 0               80.1                   4.1              52               -28
# 3               74.8                   4.0              58               -12
# 4               74.7                   4.1              57               -15
# 5               82.1                   4.1              44                16
# 11              79.8                   3.9              49               -12
#
#     knowledge_sharing_score  promotion_readiness  engagement_score  \
# 0                       4.5                 42.0               6.9
# 3                       5.3                 42.9               8.0
# 4                       5.2                 37.1               8.0
# 5                       7.0                 51.7               7.7
# 11                      5.7                 42.2               8.1
#
#     flight_risk retention_risk  manager_id  total_comp  team_lead_projects  \
# 0            29            Low    605912.0    132000.0                   0
# 3            38            Low    914277.0     98000.0                   0
# 4            27            Low    570871.0    130000.0                   0
# 5            28            Low     67837.0    157000.0                   2
# 11           26            Low    316761.0    117000.0                   0
#
#     direct_reports  is_manager management_level span_of_control  \
# 0                0       False              NaN             NaN
# 3                0       False              NaN             NaN
# 4                0       False              NaN             NaN
# 5                0       False              NaN             NaN
# 11               0       False              NaN             NaN
#
#     management_premium  span_premium
# 0                  0.0             0
# 3                  0.0             0
# 4                  0.0             0
# 5                  0.0             0
# 11                 0.0             0

# %% [markdown]
# ### Task 4

# %%
avg_salary_by_dept = df.groupby('department')['base_salary'].mean()

avg_salary_by_dept.head()
# Out:
# department
# Client Services         208804.822044
# Design & UX             188111.320755
# Engineering Delivery    187697.270471
# Product Architecture    211535.333979
# Product Strategy        215609.223301
# Name: base_salary, dtype: float64

# %% [markdown]
# ### Task 5

# %%
# %matplotlib inline

avg_salary_by_dept.plot(kind='bar',title='Average Base salary by department')
plt.xlabel('department')
plt.ylabel('Avg Base Salary')
plt.show()

# %% [markdown]
# ## Day 2

# %% [markdown]
# ### Task 1

# %%
#1.1 sorting data based on total_comp
asc_total_comp = df.sort_values('total_comp', ascending=False)
asc_total_comp.head()
# Out:
#       employee_id          full_name            department  \
# 2646       484202        Ryan Powell  Engineering Delivery
# 5188       289196        Jordan Lang       Client Services
# 152        606794          Eric Byrd      Product Strategy
# 64         194851      Barry Hensley      Product Strategy
# 4141        50678  Christina Watkins           Design & UX
#
#                      position   level   hire_date      city country    region  \
# 2646     Development Director  senior  2013-03-27  New York     USA  Americas
# 5188  Senior Program Director  senior  2012-07-27  New York     USA  Americas
# 152   Lead Product Strategist  senior  2012-06-14  New York     USA  Americas
# 64       Senior Strategy Lead  senior  2012-07-31  New York     USA  Americas
# 4141   Lead Design Strategist  senior  2016-02-13  New York     USA  Americas
#
#       remote_work_ratio  travel_percentage  base_salary  billing_rate  \
# 2646               40.0               22.1       507000          1250
# 5188               32.6               47.4       466000          1150
# 152                49.9               46.9       484000          1650
# 64                 30.6               46.0       477000          1550
# 4141               37.5               23.4       461000          1250
#
#       utilization_target  actual_utilization primary_specialization  \
# 2646                  71                59.6             Full Stack
# 5188                  62                52.9      Change Management
# 152                   50                50.0      Product Discovery
# 64                    50                53.7    Innovation Strategy
# 4141                  60                55.4         Service Design
#
#      secondary_specialization  \
# 2646                   DevOps
# 5188        Change Management
# 152         Product Discovery
# 64               Go-to-Market
# 4141            Mobile Design
#
#                                      industry_expertise  \
# 2646        Social Impact, Enterprise Software, FinTech
# 5188                    HealthTech, Enterprise Software
# 152                           HealthTech, Consumer Tech
# 64    HealthTech, Industrial Tech, E-commerce, Consu...
# 4141                     Industrial Tech, Consumer Tech
#
#                                          certifications  performance_score  \
# 2646  Azure Developer, Kubernetes, AWS Developer, Sc...               4.50
# 5188                                       Prince2, PMP               4.28
# 152                      Agile Product Management, PSPO               4.22
# 64                       PSPO, Product Management (PMP)               4.37
# 4141      Google UX Design, Human Factors International               4.09
#
#       innovation_score  delivery_quality  active_projects  \
# 2646              76.1              82.6                3
# 5188              81.4              90.6                4
# 152               66.5              76.7                3
# 64                79.7              85.6                4
# 4141              79.6              78.7                1
#
#       avg_project_complexity  avg_project_duration  avg_team_size  \
# 2646                     3.7                   8.7            6.3
# 5188                     3.2                   7.8            6.8
# 152                      4.0                   7.3            7.0
# 64                       3.5                   8.2            8.0
# 4141                     3.0                  11.0            6.0
#
#       projects_on_time  project_satisfaction  training_hours  \
# 2646              84.6                   4.1              34
# 5188              94.5                   4.5              39
# 152               87.5                   4.2              35
# 64                88.0                   4.2              22
# 4141              93.8                   4.3              32
#
#       mentorship_hours  knowledge_sharing_score  promotion_readiness  \
# 2646                20                      8.2                 12.5
# 5188                23                      8.9                  4.3
# 152                 20                      8.0                  3.7
# 64                  21                      8.3                  8.8
# 4141                37                      8.5                 15.1
#
#       engagement_score  flight_risk retention_risk  manager_id  total_comp  \
# 2646               8.3           26            Low         NaN   730115.61
# 5188               8.9           36            Low         NaN   697186.06
# 152                7.8           25            Low         NaN   691831.05
# 64                 8.6           28            Low         NaN   687853.37
# 4141               9.0           25            Low         NaN   660457.84
#
#       team_lead_projects  direct_reports  is_manager management_level  \
# 2646                   3              10        True           senior
# 5188                   1              10        True           senior
# 152                    1              10        True           senior
# 64                     4              10        True           senior
# 4141                   1              10        True           senior
#
#      span_of_control  management_premium  span_premium
# 2646      Large (7+)           147065.61         76050
# 5188      Large (7+)           161286.06         69900
# 152       Large (7+)           135231.05         72600
# 64        Large (7+)           139303.37         71550
# 4141      Large (7+)           130307.84         69150

# %%
# 1.2 fill or replace NaN values from data
missing_values = df.isna().sum()
print(missing_values)

print(df.dtypes)

print(df.info())

"""
fill_missing_values = df['total_comp'].mean()
df['total_comp'] = df['total_comp'].fillna(fill_missing_values)
"""
# Out:
# employee_id                    0
# full_name                      0
# department                     0
# position                       0
# level                          0
# hire_date                      0
# city                           0
# country                        0
# region                         0
# remote_work_ratio              0
# travel_percentage              0
# base_salary                    0
# billing_rate                   0
# utilization_target             0
# actual_utilization             0
# primary_specialization         0
# secondary_specialization       0
# industry_expertise             0
# certifications               682
# performance_score              0
# innovation_score               0
# delivery_quality               0
# active_projects                0
# avg_project_complexity         0
# avg_project_duration           0
# avg_team_size                  0
# projects_on_time               0
# project_satisfaction           0
# training_hours                 0
# mentorship_hours               0
# knowledge_sharing_score        0
# promotion_readiness            0
# engagement_score               0
# flight_risk                    0
# retention_risk                 0
# manager_id                  2623
# total_comp                     0
# team_lead_projects             0
# direct_reports                 0
# is_manager                     0
# management_level            4904
# span_of_control             4923
# management_premium             0
# span_premium                   0
# dtype: int64
# employee_id                   int64
# full_name                    object
# department                   object
# position                     object
# level                        object
# hire_date                    object
# city                         object
# country                      object
# region                       object
# remote_work_ratio           float64
# travel_percentage           float64
# base_salary                   int64
# billing_rate                  int64
# utilization_target            int64
# actual_utilization          float64
# primary_specialization       object
# secondary_specialization     object
# industry_expertise           object
# certifications               object
# performance_score           float64
# innovation_score            float64
# delivery_quality            float64
# active_projects               int64
# avg_project_complexity      float64
# avg_project_duration        float64
# avg_team_size               float64
# projects_on_time            float64
# project_satisfaction        float64
# training_hours                int64
# mentorship_hours              int64
# knowledge_sharing_score     float64
# promotion_readiness         float64
# engagement_score            float64
# flight_risk                   int64
# retention_risk               object
# manager_id                  float64
# total_comp                  float64
# team_lead_projects            int64
# direct_reports                int64
# is_manager                     bool
# management_level             object
# span_of_control              object
# management_premium          float64
# span_premium                  int64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5400 entries, 0 to 5399
# Data columns (total 44 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   employee_id               5400 non-null   int64
#  1   full_name                 5400 non-null   object
#  2   department                5400 non-null   object
#  3   position                  5400 non-null   object
#  4   level                     5400 non-null   object
#  5   hire_date                 5400 non-null   object
#  6   city                      5400 non-null   object
#  7   country                   5400 non-null   object
#  8   region                    5400 non-null   object
#  9   remote_work_ratio         5400 non-null   float64
#  10  travel_percentage         5400 non-null   float64
#  11  base_salary               5400 non-null   int64
#  12  billing_rate              5400 non-null   int64
#  13  utilization_target        5400 non-null   int64
#  14  actual_utilization        5400 non-null   float64
#  15  primary_specialization    5400 non-null   object
#  16  secondary_specialization  5400 non-null   object
#  17  industry_expertise        5400 non-null   object
#  18  certifications            4718 non-null   object
#  19  performance_score         5400 non-null   float64
#  20  innovation_score          5400 non-null   float64
#  21  delivery_quality          5400 non-null   float64
#  22  active_projects           5400 non-null   int64
#  23  avg_project_complexity    5400 non-null   float64
#  24  avg_project_duration      5400 non-null   float64
#  25  avg_team_size             5400 non-null   float64
#  26  projects_on_time          5400 non-null   float64
#  27  project_satisfaction      5400 non-null   float64
#  28  training_hours            5400 non-null   int64
#  29  mentorship_hours          5400 non-null   int64
#  30  knowledge_sharing_score   5400 non-null   float64
#  31  promotion_readiness       5400 non-null   float64
#  32  engagement_score          5400 non-null   float64
#  33  flight_risk               5400 non-null   int64
#  34  retention_risk            5400 non-null   object
#  35  manager_id                2777 non-null   float64
#  36  total_comp                5400 non-null   float64
#  37  team_lead_projects        5400 non-null   int64
#  38  direct_reports            5400 non-null   int64
#  39  is_manager                5400 non-null   bool
#  40  management_level          496 non-null    object
#  41  span_of_control           477 non-null    object
#  42  management_premium        5400 non-null   float64
#  43  span_premium              5400 non-null   int64
# dtypes: bool(1), float64(17), int64(11), object(15)
# memory usage: 1.8+ MB
# None
# "\nfill_missing_values = df['total_comp'].mean()\ndf['total_comp'] = df['total_comp'].fillna(fill_missing_values)\n"

# %%
#1.3 creating a computed column
df['bonus'] = df['base_salary'] * 0.1
df
# Out:
#       employee_id         full_name            department  \
# 0          670487   Patrick Sanchez  Engineering Delivery
# 1          146316     Megan Mcclain  Product Architecture
# 2           91161      Amanda Davis       Client Services
# 3          243962   Alyssa Gonzalez  Engineering Delivery
# 4          681453     Jennifer Cole  Engineering Delivery
# ...           ...               ...                   ...
# 5395        17844  Elizabeth Morrow  Engineering Delivery
# 5396       836591    Sophia Bennett           Design & UX
# 5397        23701       Clayton May           Design & UX
# 5398       370275    Danny Anderson           Design & UX
# 5399       428841     John Cardenas           Design & UX
#
#                       position   level   hire_date           city    country  \
# 0          Associate Developer   entry  2023-03-26       New York        USA
# 1           Solution Architect     mid  2020-05-19         Berlin    Germany
# 2     Client Success Associate   entry  2023-07-22      Singapore  Singapore
# 3          Associate Developer   entry  2022-07-05      Singapore  Singapore
# 4                QA Engineer I   entry  2022-11-07       New York        USA
# ...                        ...     ...         ...            ...        ...
# 5395      Development Director  senior  2017-03-11  San Francisco        USA
# 5396               Design Lead     mid  2020-08-14       New York        USA
# 5397             UI Designer I   entry  2022-08-16      Singapore  Singapore
# 5398         Design Strategist     mid  2021-05-30       New York        USA
# 5399    Lead Design Strategist  senior  2014-01-28       New York        USA
#
#         region  remote_work_ratio  travel_percentage  base_salary  \
# 0     Americas               24.7                1.8       132000
# 1         EMEA               37.3               18.8       176000
# 2         APAC               21.9               28.8        98000
# 3         APAC               23.2                4.5        98000
# 4     Americas               11.1                1.5       130000
# ...        ...                ...                ...          ...
# 5395  Americas               40.2               23.5       396000
# 5396  Americas               22.8               18.5       156000
# 5397      APAC               25.3                7.1       110000
# 5398  Americas               25.7               16.9       174000
# 5399  Americas               46.2               21.9       364000
#
#       billing_rate  utilization_target  actual_utilization  \
# 0              250                  90                79.4
# 1              350                  68                67.4
# 2              150                  89                93.8
# 3              150                  90                93.6
# 4              250                  90                77.2
# ...            ...                 ...                 ...
# 5395           950                  70                67.5
# 5396           300                  77                65.4
# 5397           200                  82                72.6
# 5398           350                  77                68.9
# 5399          1050                  62                52.6
#
#      primary_specialization secondary_specialization  \
# 0              Cloud Native             Cloud Native
# 1     Security Architecture    Security Architecture
# 2            Agile Delivery       Strategic Planning
# 3        Mobile Development       Mobile Development
# 4                  Frontend                 Frontend
# ...                     ...                      ...
# 5395     Mobile Development                  Backend
# 5396        Design Thinking            User Research
# 5397         Design Systems           Service Design
# 5398         Service Design            Mobile Design
# 5399          Mobile Design            Mobile Design
#
#                                      industry_expertise  \
# 0                    Enterprise Software, Consumer Tech
# 1     HealthTech, Social Impact, Consumer Tech, Indu...
# 2                    Consumer Tech, FinTech, E-commerce
# 3                    Social Impact, Enterprise Software
# 4     Industrial Tech, HealthTech, Enterprise Softwa...
# ...                                                 ...
# 5395            Enterprise Software, EdTech, E-commerce
# 5396                           Industrial Tech, FinTech
# 5397  Enterprise Software, Industrial Tech, Social I...
# 5398           HealthTech, Enterprise Software, FinTech
# 5399         Industrial Tech, Social Impact, E-commerce
#
#                                          certifications  performance_score  \
# 0                           Scrum Master, AWS Developer               3.65
# 1     Azure Architect, AWS Solutions Architect, Goog...               3.92
# 2                                                   PMP               3.01
# 3                           Azure Developer, Kubernetes               4.20
# 4                                          Scrum Master               3.42
# ...                                                 ...                ...
# 5395  Scrum Master, Kubernetes, AWS Developer, Azure...               3.33
# 5396                      Interaction Design Foundation               4.00
# 5397      Human Factors International, Google UX Design               3.48
# 5398                                   Google UX Design               4.02
# 5399      Human Factors International, Google UX Design               4.42
#
#       innovation_score  delivery_quality  active_projects  \
# 0                 66.9              78.6                2
# 1                 90.0              86.3                3
# 2                 82.0              82.0                3
# 3                 71.3              83.1                2
# 4                 75.7              87.0                2
# ...                ...               ...              ...
# 5395              73.8              85.7                3
# 5396              80.1              89.8                2
# 5397              81.6              82.5                1
# 5398              69.0              80.2                1
# 5399              67.6              72.4                3
#
#       avg_project_complexity  avg_project_duration  avg_team_size  \
# 0                        2.5                   8.5            5.5
# 1                        3.3                   9.7            7.0
# 2                        1.7                  10.0            4.7
# 3                        2.5                   4.0            4.5
# 4                        1.0                   3.0            7.0
# ...                      ...                   ...            ...
# 5395                     4.7                   4.3            6.3
# 5396                     1.5                  12.0            9.0
# 5397                     3.0                   4.0            3.0
# 5398                     2.0                   8.0            5.0
# 5399                     4.0                   6.7            4.7
#
#       projects_on_time  project_satisfaction  training_hours  \
# 0                 80.1                   4.1              52
# 1                 60.0                   3.9              48
# 2                 86.0                   4.3              49
# 3                 74.8                   4.0              58
# 4                 74.7                   4.1              57
# ...                ...                   ...             ...
# 5395              60.0                   4.4              25
# 5396              87.3                   4.1              49
# 5397              78.4                   4.1              55
# 5398              82.2                   4.3              30
# 5399              86.5                   4.2             100
#
#       mentorship_hours  knowledge_sharing_score  promotion_readiness  \
# 0                  -28                      4.5                 42.0
# 1                    3                      7.3                 79.6
# 2                  -23                      4.5                 35.3
# 3                  -12                      5.3                 42.9
# 4                  -15                      5.2                 37.1
# ...                ...                      ...                  ...
# 5395                39                      8.4                 11.8
# 5396                 0                      7.2                 73.6
# 5397               -26                      5.3                 43.8
# 5398                 3                      7.4                 61.4
# 5399                20                      9.4                 18.1
#
#       engagement_score  flight_risk retention_risk  manager_id  total_comp  \
# 0                  6.9           29            Low    605912.0   132000.00
# 1                  8.2           42         Medium         NaN   176000.00
# 2                  6.9           40            Low    574842.0    98000.00
# 3                  8.0           38            Low    914277.0    98000.00
# 4                  8.0           27            Low    570871.0   130000.00
# ...                ...          ...            ...         ...         ...
# 5395               7.2           30            Low         NaN   396000.00
# 5396               7.0           27            Low         NaN   198432.62
# 5397               7.4           27            Low    520760.0   110000.00
# 5398               8.1           28            Low         NaN   174000.00
# 5399               9.3           30            Low         NaN   532394.97
#
#       team_lead_projects  direct_reports  is_manager management_level  \
# 0                      0               0       False              NaN
# 1                      1               0       False              NaN
# 2                      0               0       False              NaN
# 3                      0               0       False              NaN
# 4                      0               0       False              NaN
# ...                  ...             ...         ...              ...
# 5395                   2               0       False              NaN
# 5396                   0               2        True              mid
# 5397                   0               0       False              NaN
# 5398                   0               0       False              NaN
# 5399                   2              10        True           senior
#
#      span_of_control  management_premium  span_premium    bonus
# 0                NaN                0.00             0  13200.0
# 1                NaN                0.00             0  17600.0
# 2                NaN                0.00             0   9800.0
# 3                NaN                0.00             0   9800.0
# 4                NaN                0.00             0  13000.0
# ...              ...                 ...           ...      ...
# 5395             NaN                0.00             0  39600.0
# 5396     Small (1-3)            34632.62          7800  15600.0
# 5397             NaN                0.00             0  11000.0
# 5398             NaN                0.00             0  17400.0
# 5399      Large (7+)           113794.97         54600  36400.0
#
# [5400 rows x 45 columns]

# %% [markdown]
# ### Task 2

# %%
my_list = [1, 2, 3, 4, 5]

# converting list into an array
my_array = np.array(my_list)

# performing a vectorized operation
result_array = my_array + 10

result_array
"""
List vs Array:
    list's are relatively slow in runtime, as they check every value
    type before making changes to them.
    But, in Array's are designed to hold elements of same dtype, allowing
    to store data more compactly in memory and perform opertions much
    more efficiently.
"""
# Out:
# "\nList vs Array:\n    list's are relatively slow in runtime, as they check every value\n    type before making changes to them.\n    But, in Array's are designed to hold elements of same dtype, allowing\n    to store data more compactly in memory and perform opertions much\n    more efficiently.\n"

# %% [markdown]
# ## Day 3

# %% [markdown]
# ### Task 1

# %%
# computing descriptive statistics (it doesn't do justice to the data at hand)
df.describe()
# Out:
#          employee_id  remote_work_ratio  travel_percentage    base_salary  \
# count    5400.000000        5400.000000        5400.000000    5400.000000
# mean   500086.584630          28.741574          20.411407  200002.407407
# std    287402.686801           9.614284          14.927358   97202.638016
# min        63.000000          10.000000           0.000000   82000.000000
# 25%    254712.500000          21.700000           7.700000  119000.000000
# 50%    500614.000000          28.400000          18.500000  177000.000000
# 75%    747426.750000          36.000000          31.500000  242000.000000
# max    999600.000000          50.000000          54.900000  526000.000000
#
#        billing_rate  utilization_target  actual_utilization  \
# count   5400.000000         5400.000000         5400.000000
# mean     456.712963           75.735556           71.236389
# std      313.741634           11.364642           11.946029
# min      100.000000           50.000000           50.000000
# 25%      250.000000           68.000000           62.500000
# 50%      350.000000           77.000000           71.950000
# 75%      550.000000           86.000000           80.200000
# max     1950.000000           90.000000           95.000000
#
#        performance_score  innovation_score  delivery_quality  active_projects  \
# count        5400.000000       5400.000000       5400.000000      5400.000000
# mean            3.696035         74.905389         81.842444         2.534630
# std             0.391797          7.684870          6.747692         1.053445
# min             2.500000         50.000000         60.000000         1.000000
# 25%             3.430000         69.800000         77.200000         2.000000
# 50%             3.700000         75.000000         81.900000         3.000000
# 75%             3.970000         80.200000         86.700000         3.000000
# max             4.500000         90.000000         95.000000         5.000000
#
#        avg_project_complexity  avg_project_duration  avg_team_size  \
# count             5400.000000           5400.000000    5400.000000
# mean                 2.647463              7.479315       6.509037
# std                  1.003877              2.035323       1.598095
# min                  1.000000              3.000000       3.000000
# 25%                  2.000000              6.000000       5.500000
# 50%                  2.700000              7.500000       6.500000
# 75%                  3.400000              9.000000       7.700000
# max                  5.000000             12.000000      10.000000
#
#        projects_on_time  project_satisfaction  training_hours  \
# count       5400.000000           5400.000000     5400.000000
# mean          83.290241              4.169352       41.583704
# std            7.646534              0.181919       13.669451
# min           60.000000              3.500000       10.000000
# 25%           78.600000              4.100000       33.000000
# 50%           83.200000              4.200000       41.000000
# 75%           88.200000              4.300000       49.000000
# max          100.000000              4.600000      100.000000
#
#        mentorship_hours  knowledge_sharing_score  promotion_readiness  \
# count       5400.000000              5400.000000          5400.000000
# mean           1.512593                 6.534722            45.502907
# std           20.508308                 1.623237            21.737807
# min          -30.000000                 2.500000             0.000000
# 25%          -16.000000                 5.000000            29.000000
# 50%            0.000000                 6.800000            46.900000
# 75%           19.000000                 8.000000            64.425000
# max           40.000000                 9.500000            92.000000
#
#        engagement_score  flight_risk     manager_id     total_comp  \
# count       5400.000000  5400.000000    2777.000000    5400.000000
# mean           7.948426    32.465741  495820.460209  207131.904996
# std            1.033646    11.822855  275658.484314  105411.649890
# min            4.000000    15.000000    8948.000000   82000.000000
# 25%            7.500000    24.000000  294301.000000  119000.000000
# 50%            8.000000    30.000000  484405.000000  183000.000000
# 75%            8.600000    39.000000  717307.000000  259000.000000
# max           10.000000    93.000000  998944.000000  730115.610000
#
#        team_lead_projects  direct_reports  management_premium  span_premium  \
# count         5400.000000     5400.000000         5400.000000   5400.000000
# mean             0.840556        0.514259         4844.127219   2285.370370
# std              1.110968        1.899147        17713.683031   8907.666546
# min              0.000000        0.000000            0.000000      0.000000
# 25%              0.000000        0.000000            0.000000      0.000000
# 50%              0.000000        0.000000            0.000000      0.000000
# 75%              1.000000        0.000000            0.000000      0.000000
# max              5.000000       10.000000       161286.060000  76050.000000
#
#               bonus
# count   5400.000000
# mean   20000.240741
# std     9720.263802
# min     8200.000000
# 25%    11900.000000
# 50%    17700.000000
# 75%    24200.000000
# max    52600.000000

# %% [markdown]
# #### Define the Objective
#
# You want to extract meaningful insights from numerical columns by grouping, analyzing distributions, and checking correlations. Your goal is to uncover patterns such as:
#
# - Salary differences across departments
#
# - Utilization trends
#
# - Performance score impact on flight risk
#
# ---
#
# Columns used to do above things:
#
# `base_salary`, `billing_rate`, `performance_score`, `actual_utilization`, `utilization_target`, `flight_risk`

# %%
"""
By Department

- What's the average salary per department?
- Which department has the highest billing rate?
- Does utilization vary significantly across departments?
"""

# 1️⃣ Average salary per region
avg_salary_by_region = df.groupby('region')['base_salary'].mean()


# 2️⃣ Region with highest billing rate
higest_billing_rate = df.groupby('region')['billing_rate'].idxmax()


# 3️⃣ utilization vary significantly across departments
util_variation_stats = df.groupby('department')[['utilization_target','actual_utilization']].agg(['mean', 'std'])
round(util_variation_stats, 2)
# Out:
#                      utilization_target       actual_utilization
#                                    mean   std               mean    std
# department
# Client Services                   77.17  9.06              72.29  10.80
# Design & UX                       75.91  9.51              71.02  10.68
# Engineering Delivery              84.48  7.67              79.71   9.44
# Product Architecture              70.09  9.06              65.83   9.67
# Product Strategy                  63.96  9.75              60.60   9.10
